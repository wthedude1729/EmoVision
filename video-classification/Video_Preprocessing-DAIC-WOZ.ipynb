# %% [markdown]
# # Imports and Installations

# %%
# !pip install kaggle
from google.colab import drive
drive.mount('/content/drive')
# !mkdir ~/.kaggle
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d harshitajakiya/daic-woz-video
# Out:
# cp: cannot stat '/content/drive/My': No such file or directory
# cp: cannot stat 'Drive/Machine': No such file or directory
# cp: cannot stat 'Learning/COSMOS/FINAL_PROJECT/DER/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# ...
# Dataset URL: https://www.kaggle.com/datasets/harshitajakiya/daic-woz-video
# License(s): Apache 2.0
# ...
# 100% 10.4G/10.4G [10:02<00:00, 21.3MB/s]
# 100% 10.4G/10.4G [10:02<00:00, 18.5MB/s]

# %%
# !unzip daic-woz-video.zip
# Out:
# Archive:  daic-woz-video.zip
#   inflating: 300_video_combined.csv
#   inflating: 301_video_combined.csv
#   inflating: 302_video_combined.csv
#   inflating: 303_video_combined.csv
#   inflating: 304_video_combined.csv
#   inflating: 305_video_combined.csv
#   inflating: 306_video_combined.csv
#   inflating: 307_video_combined.csv
#   inflating: 308_video_combined.csv
#   inflating: 309_video_combined.csv
#   inflating: 310_video_combined.csv
#   inflating: 311_video_combined.csv
#   inflating: 312_video_combined.csv
#   inflating: 313_video_combined.csv
#   inflating: 314_video_combined.csv
#   inflating: 315_video_combined.csv
#   inflating: 316_video_combined.csv
#   inflating: 317_video_combined.csv
#   inflating: 318_video_combined.csv
#   inflating: 319_video_combined.csv
#   inflating: 320_video_combined.csv
#   inflating: 321_video_combined.csv
#   inflating: 322_video_combined.csv
#   inflating: 323_video_combined.csv
#   inflating: 324_video_combined.csv
# ...

# %% [markdown]
# # Processing the Videos
