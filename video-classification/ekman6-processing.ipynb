# %% [markdown]
# # Imports

# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Deep learning with TensorFlow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.utils import to_categorical

# Deep learning with PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchvision import models

# Natural Language Processing (NLP)
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Miscellaneous
import os
import re
import time
import pickle

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Extract Audio from Video

# %%
# !pip install moviepy
from moviepy.editor import VideoFileClip

# %%
directory = "/content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6/"
to_directory = "/content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/"
folders = ["anger/", "disgust/", "fear/", "joy/", "sadness/", "surprise/"]

id = 0
i = 0
cnt = 0
moviepy_is_weak = 0

while True:
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break
# Out:
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/0.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/1.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/2.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/3.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/4.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/5.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/6.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/7.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/8.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/9.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/10.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/11.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/12.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/13.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/14.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/15.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/16.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/17.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/18.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/19.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/20.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/21.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/22.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/23.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/24.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/25.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/26.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/27.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/28.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/29.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/30.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/31.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/32.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/33.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/34.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/35.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/36.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/37.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/38.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/39.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/40.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/41.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/42.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/43.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/44.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/45.mp3
# MoviePy - Done.

# %%
moviepy_is_weak = 0

while True:
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    print(cnt, i)
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break
# Out:
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/46.mp3
# MoviePy - Done.
# 47 0
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/47.mp3
# MoviePy - Done.
# 48 0
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/48.mp3
# MoviePy - Done.
# 49 0
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/anger/49.mp3
# MoviePy - Done.
# 50 0
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/50.mp3
# MoviePy - Done.
# 51 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/51.mp3
# MoviePy - Done.
# 52 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/52.mp3
# MoviePy - Done.
# 53 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/53.mp3
# MoviePy - Done.
# 54 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/54.mp3
# MoviePy - Done.
# 55 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/55.mp3
# MoviePy - Done.
# 56 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/56.mp3
# MoviePy - Done.
# 57 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/57.mp3
# MoviePy - Done.
# 58 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/58.mp3
# MoviePy - Done.
# 59 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/59.mp3
# MoviePy - Done.
# 60 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/60.mp3
# MoviePy - Done.
# 61 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/61.mp3
# MoviePy - Done.
# 62 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/62.mp3
# MoviePy - Done.
# 63 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/63.mp3
# MoviePy - Done.
# 64 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/64.mp3
# MoviePy - Done.
# 65 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/65.mp3
# MoviePy - Done.
# 66 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/66.mp3
# MoviePy - Done.
# 67 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/67.mp3
# MoviePy - Done.
# 68 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/68.mp3
# MoviePy - Done.
# 69 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/69.mp3
# MoviePy - Done.
# 70 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/70.mp3
# MoviePy - Done.
# 71 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/71.mp3
# MoviePy - Done.
# 72 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/72.mp3
# MoviePy - Done.
# 73 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/73.mp3
# MoviePy - Done.
# 74 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/74.mp3
# MoviePy - Done.
# 75 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/75.mp3
# MoviePy - Done.
# 76 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/76.mp3
# MoviePy - Done.
# 77 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/77.mp3
# MoviePy - Done.
# 78 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/78.mp3
# MoviePy - Done.
# 79 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/79.mp3
# MoviePy - Done.
# 80 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-cfb7d254920f> in <cell line: 3>()
#       7     clip = VideoFileClip(directory + folders[i] + file)
#       8     audio = clip.audio
# ----> 9     audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
#      10     audio.close()
#      11     clip.close()
#
# AttributeError: 'NoneType' object has no attribute 'write_audiofile'

# %%
moviepy_is_weak = 0

while True:
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    #print(cnt, i)
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break
# Out:
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/80.mp3
# MoviePy - Done.
# 81 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/81.mp3
# MoviePy - Done.
# 82 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/82.mp3
# MoviePy - Done.
# 83 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/83.mp3
# MoviePy - Done.
# 84 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/84.mp3
# MoviePy - Done.
# 85 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/85.mp3
# MoviePy - Done.
# 86 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/86.mp3
# MoviePy - Done.
# 87 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/87.mp3
# MoviePy - Done.
# 88 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/88.mp3
# MoviePy - Done.
# 89 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/89.mp3
# MoviePy - Done.
# 90 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/90.mp3
# MoviePy - Done.
# 91 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/91.mp3
# MoviePy - Done.
# 92 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/92.mp3
# MoviePy - Done.
# 93 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/93.mp3
# MoviePy - Done.
# 94 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/94.mp3
# MoviePy - Done.
# 95 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/95.mp3
# MoviePy - Done.
# 96 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/96.mp3
# MoviePy - Done.
# 97 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/97.mp3
# MoviePy - Done.
# 98 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/98.mp3
# MoviePy - Done.
# 99 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/disgust/99.mp3
# MoviePy - Done.
# 100 1
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/100.mp3
# MoviePy - Done.
# 101 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/101.mp3
# MoviePy - Done.
# 102 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/102.mp3
# MoviePy - Done.
# 103 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/103.mp3
# MoviePy - Done.
# 104 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/104.mp3
# MoviePy - Done.
# 105 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/105.mp3
# MoviePy - Done.
# 106 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/106.mp3
# MoviePy - Done.
# 107 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/107.mp3
# MoviePy - Done.
# 108 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/108.mp3
# MoviePy - Done.
# 109 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/109.mp3
# MoviePy - Done.
# 110 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/110.mp3
# MoviePy - Done.
# 111 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/111.mp3
# MoviePy - Done.
# 112 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/112.mp3
# MoviePy - Done.
# 113 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/113.mp3
# MoviePy - Done.
# 114 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/114.mp3
# MoviePy - Done.
# 115 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/115.mp3
# MoviePy - Done.
# 116 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/116.mp3
# MoviePy - Done.
# 117 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/117.mp3
# MoviePy - Done.
# 118 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/118.mp3
# MoviePy - Done.
# 119 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/119.mp3
# MoviePy - Done.
# 120 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/120.mp3
# MoviePy - Done.
# 121 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/121.mp3
# MoviePy - Done.
# 122 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/122.mp3
# MoviePy - Done.
# 123 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/123.mp3
# MoviePy - Done.
# 124 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/124.mp3
# MoviePy - Done.
# 125 2
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/125.mp3
# MoviePy - Done.
# 126 2

# %%
moviepy_is_weak = 0

while True:
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    #print(cnt, i)
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break
# Out:
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/126.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/127.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/128.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/129.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/130.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/131.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/132.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/133.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/134.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/135.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/136.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/137.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/138.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/139.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/140.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/141.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/142.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/143.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/144.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/145.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/146.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/147.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/148.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/fear/149.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/150.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/151.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/152.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/153.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/154.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/155.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/156.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/157.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/158.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/159.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/160.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/161.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/162.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/163.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/164.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/165.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/166.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/167.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/168.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/169.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/170.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/171.mp3
# MoviePy - Done.

# %%
moviepy_is_weak = 0

while True:
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    #print(cnt, i)
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break
# Out:
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/172.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/173.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/174.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/175.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/176.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/177.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/178.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/179.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/180.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/181.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/182.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/183.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/184.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/185.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/186.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/187.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/188.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/189.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/190.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/191.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/192.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/193.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/194.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/195.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/196.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/197.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/198.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/joy/199.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/200.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/201.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/202.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/203.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/204.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/205.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/206.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/207.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/208.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/209.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/210.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/211.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/212.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/213.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/214.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/215.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/216.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/217.mp3
# MoviePy - Done.

# %%
moviepy_is_weak = 0

while True:
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    #print(cnt, i)
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break
# Out:
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/218.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/219.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/220.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/221.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/222.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/223.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/224.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/225.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/226.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/227.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/228.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/229.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/230.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/231.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/232.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/233.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/234.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/235.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/236.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/237.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/238.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/239.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/240.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/241.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/242.mp3
# MoviePy - Done.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-6534ec27fa1d> in <cell line: 3>()
#       7     clip = VideoFileClip(directory + folders[i] + file)
#       8     audio = clip.audio
# ----> 9     audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
#      10     audio.close()
#      11     clip.close()
#
# AttributeError: 'NoneType' object has no attribute 'write_audiofile'

# %%
moviepy_is_weak = 0

while True:
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    #print(cnt, i)
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break
# Out:
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/243.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/244.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/245.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/246.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/247.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/248.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/sadness/249.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/250.mp3
# chunk:   0%|          | 0/1325 [00:00<?, ?it/s, now=None]
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/moviepy/audio/io/ffmpeg_audiowriter.py in write_frames(self, frames_array)
#      73             try:
# ---> 74                 self.proc.stdin.write(frames_array.tobytes())
#      75             except NameError:
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-6534ec27fa1d> in <cell line: 3>()
#       7     clip = VideoFileClip(directory + folders[i] + file)
#       8     audio = clip.audio
# ----> 9     audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
#      10     audio.close()
#      11     clip.close()
#
# <decorator-gen-200> in write_audiofile(self, filename, fps, nbytes, buffersize, codec, bitrate, ffmpeg_params, write_logfile, verbose, logger)
#
# /usr/local/lib/python3.10/dist-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# /usr/local/lib/python3.10/dist-packages/moviepy/audio/AudioClip.py in write_audiofile(self, filename, fps, nbytes, buffersize, codec, bitrate, ffmpeg_params, write_logfile, verbose, logger)
#     204                                  "parameter in write_audiofile.")
#     205
# --> 206         return ffmpeg_audiowrite(self, filename, fps, nbytes, buffersize,
#     207                                  codec=codec, bitrate=bitrate,
#     208                                  write_logfile=write_logfile, verbose=verbose,
#
# <decorator-gen-164> in ffmpeg_audiowrite(clip, filename, fps, nbytes, buffersize, codec, bitrate, write_logfile, verbose, ffmpeg_params, logger)
#
# /usr/local/lib/python3.10/dist-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# /usr/local/lib/python3.10/dist-packages/moviepy/audio/io/ffmpeg_audiowriter.py in ffmpeg_audiowrite(clip, filename, fps, nbytes, buffersize, codec, bitrate, write_logfile, verbose, ffmpeg_params, logger)
#     168                                   nbytes=nbytes, fps=fps,
#     169                                   logger=logger):
# --> 170         writer.write_frames(chunk)
#     171
#     172     writer.close()
#
# /usr/local/lib/python3.10/dist-packages/moviepy/audio/io/ffmpeg_audiowriter.py in write_frames(self, frames_array)
#     115                           "Ubuntu/Debian repos are deprecated)."))
#     116
# --> 117             raise IOError(error)
#     118
#     119     def close(self):
#
# OSError: [Errno 32] Broken pipe
#
# MoviePy error: FFMPEG encountered the following error while writing file /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/250.mp3:
#
# b'/content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/250.mp3: No such file or directory\n'
#
# In case it helps, make sure you are using a recent version of FFMPEG (the versions in the Ubuntu/Debian repos are deprecated).

# %%
# !pip install moviepy
from moviepy.editor import VideoFileClip

directory = "/content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6/"
to_directory = "/content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/"
folders = ["anger/", "disgust/", "fear/", "joy/", "sadness/", "surprise/"]
moviepy_is_weak = 0
cnt = 250
id = 250
i = 5

while True:
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    #print(cnt, i)
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.66.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.25.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.34.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.5.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy) (71.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2024.7.4)
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/250.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/251.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/252.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/253.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/254.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/255.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/256.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/257.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/258.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/259.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/260.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/261.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/262.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/263.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/264.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/265.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/266.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/267.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/268.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/269.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/270.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/271.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/272.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/273.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/274.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/275.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/276.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/277.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/278.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/279.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/280.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/281.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/282.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/283.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/284.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/285.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/286.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/287.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/288.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/289.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/290.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/291.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/292.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/293.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/294.mp3
# MoviePy - Done.
# MoviePy - Writing audio in /content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/surprise/295.mp3
# MoviePy - Done.

# %%
moviepy_is_weak = 0

while True:
  if (i == 6):
    break
  path = directory + folders[i]
  for file in os.listdir(path):
    filename = os.fsdecode(file)
    clip = VideoFileClip(directory + folders[i] + file)
    audio = clip.audio
    audio.write_audiofile(to_directory + folders[i] + str(id) + ".mp3")
    audio.close()
    clip.close()
    id += 1
    cnt += 1
    moviepy_is_weak += 1
    #print(cnt, i)
    if cnt%50 == 0:
      i += 1
      break
    if moviepy_is_weak == 46:
      break
  if moviepy_is_weak == 46:
    break

# %%
print("good job, moviepy")
# Out:
# good job, moviepy

# %% [markdown]
# # Extract Text from Audio

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.37.1-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Downloading openai-1.37.1-py3-none-any.whl (337 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 24.3 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.4 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.37.1

# %%
from openai import OpenAI
key = ""
client = OpenAI(api_key = key)
directory = "/content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_audio/"
folders = ["anger/", "disgust/", "fear/", "joy/", "sadness/", "surprise/"]

def translated_text(filename):
  audio_file = open(filename, "rb")
  translation = client.audio.translations.create(
    model="whisper-1",
    file=audio_file,
    temperature = 0.90
  )
  return translation.text

texts = []

i = 0
path = directory + folders[i]
for file in os.listdir(path):
  filename = os.fsdecode(file)
  tt = translated_text(path + filename)
  texts.append(tt)

# %% [markdown]
# Wait a minute (for ChatGPT)

# %%
i = 1
path = directory + folders[i]
for file in os.listdir(path):
  filename = os.fsdecode(file)
  tt = translated_text(path + filename)
  texts.append(tt)

# %% [markdown]
# Wait a minute (for ChatGPT)

# %%
i = 2
path = directory + folders[i]
for file in os.listdir(path):
  filename = os.fsdecode(file)
  tt = translated_text(path + filename)
  texts.append(tt)

# %%
print(len(texts))
# Out:
# 150

# %% [markdown]
# Wait a minute (for ChatGPT)

# %%
i = 3
path = directory + folders[i]
for file in os.listdir(path):
  filename = os.fsdecode(file)
  tt = translated_text(path + filename)
  texts.append(tt)

# %% [markdown]
# Wait a minute (for ChatGPT)

# %%
i = 4
path = directory + folders[i]
for file in os.listdir(path):
  filename = os.fsdecode(file)
  tt = translated_text(path + filename)
  texts.append(tt)

# %% [markdown]
# Wait a minute (for ChatGPT)

# %%
i = 5
path = directory + folders[i]
for file in os.listdir(path):
  filename = os.fsdecode(file)
  tt = translated_text(path + filename)
  texts.append(tt)

# %% [markdown]
# Write to a .csv file

# %%
import csv

with open("/content/drive/My Drive/Machine Learning/COSMOS/FINAL_PROJECT/DER/ekman6_texts/transcripts.csv", 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(texts)

# %% [markdown]
# # Create Spectrograms

# %% [markdown]
# # Cut the Videos
